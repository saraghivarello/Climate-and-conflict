# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import statsmodels.formula.api as smf
import torch

# %%
file = r"C:\Users\PcLaptop\Documents\GitHub\Climate-and-conflict\reg_TA_PA.csv"
df = pd.read_csv(file)
df['admin1'] = df['admin1'].str.replace('Lower Shabelle', 'Lower_Shabelle')
df['admin1'] = df['admin1'].str.replace('Middle Shabelle', 'Middle_Shabelle')
df['admin1'] = df['admin1'].str.replace('Lower Juba', 'Lower_Juba')
df['admin1'] = df['admin1'].str.replace('Middle Juba', 'Middle_Juba')
df['admin1'] = df['admin1'].str.replace('Woqooyi Galbeed', 'Woqooyi_Galbeed')

# %%
#Create a new column with the drought lenght DL
df['DL'] = 0
mask = df['TA'] > 0
# Create a group identifier for each consecutive group
group_id = (mask != mask.shift()).cumsum()
# Calculate the count within each group
count = df.groupby(group_id).cumcount() + 1
# Assign the count values to the 'DL' column
df['DL'] = np.where(mask, count, 0)
#in df remove all rows that contain a NaN
df = df.dropna()
df.reset_index(drop=True, inplace=True)

# %%
#Create the dummy variables, one for each country
df_dummies = pd.get_dummies(df['admin1'])
df_with_dummies = df.join(df_dummies)

#Create the dummy variables, one for each month
df['month'] = pd.DatetimeIndex(df['time_x']).month_name()
df_dummies_m = pd.get_dummies(df['month'])
df_with_dummies = df_with_dummies.join(df_dummies_m)
df_with_dummies['month'] = pd.DatetimeIndex(df['time_x']).month

#Create the dummy variables, one for each for each country-month pair
df_dummies_mr = pd.get_dummies(df['admin1'] + df['month'])
df_with_dummies = df_with_dummies.join(df_dummies_mr)

df_with_dummies = df_with_dummies.replace({True: 1, False: 0})

# %%
#Create tensors for TA, PA, DL and random noise

tensors_ta = []
tensors_pa = []
tensors_dl = []

# Iterate over unique regions
for region in df['admin1'].unique():
    # Filter the DataFrame for the current region
    region_df = df[df['admin1'] == region]
    
    # Get the 'TA' and 'PA' values for the current region as numpy arrays
    ta_values = region_df['TA'].values
    pa_values = region_df['PA'].values 
    dl_values = region_df['DL'].values
        
    # Create a tensor from the numpy arrays
    tensor_t = torch.tensor(ta_values)
    tensor_p = torch.tensor(pa_values)
    tensor_d = torch.tensor(dl_values)
    
    # Append the tensor to the list
    tensors_ta.append(tensor_t)
    tensors_pa.append(tensor_p)
    tensors_dl.append(tensor_d)

ta_tensor = torch.stack(tensors_ta, dim=0)
pa_tensor = torch.stack(tensors_pa, dim=0)
dl_tensor = torch.stack(tensors_dl, dim=0)

# Create a tensor with random noise
noise_gauss = torch.tensor(np.random.normal(0, 0.1, ta_tensor.size()), dtype=torch.float)
noise_uniform = torch.randn_like(ta_tensor)

# %%
#Regression formula with tensors to get synthetic data

c_tensor = ta_tensor + pa_tensor + dl_tensor + torch.tensor(np.random.normal(0, 1, ta_tensor.size()), dtype=torch.float)

#from c_tensor create an array 

df_with_dummies['conflicts_synth'] = c_tensor.view(-1,1).numpy()

# %%
#Create formula for OLS with synthetic data

y_var_name = 'conflicts_synth'
X_var_names = ['TA','PA','DL']

unit_names = df['admin1'].unique().tolist()
unit_names.sort()
unit_names_t = df['month'].unique().tolist()
unit_names_mr = (df['admin1'] + df['month']).unique().tolist()

lsdv_expr = y_var_name + ' ~ '
i = 0
for X_var_name in X_var_names:
    if i > 0:
        lsdv_expr = lsdv_expr + ' + ' + X_var_name
    else:
        lsdv_expr = lsdv_expr + X_var_name
    i = i + 1
for dummy_name in unit_names[:-1]:
    lsdv_expr = lsdv_expr + ' + ' + dummy_name
for dummy_name_t in unit_names_t[:-1]:
    lsdv_expr = lsdv_expr + ' + ' + dummy_name_t
for dummy_name_mr in unit_names_mr[:-1]:
    lsdv_expr = lsdv_expr + ' + ' + dummy_name_mr
 
print('Regression expression for OLS with dummies = ' + lsdv_expr)
# Out:
# Regression expression for OLS with dummies = conflicts_synth ~ TA + PA + DL + Awdal + Bakool + Banadir + Bari + Bay + Galgaduud + Gedo + Hiraan + Lower_Juba + Lower_Shabelle + Middle_Juba + Middle_Shabelle + Mudug + Nugaal + Sanaag + Sool + Togdheer + April + May + June + July + August + September + October + November + December + January + February + AwdalApril + AwdalMay + AwdalJune + AwdalJuly + AwdalAugust + AwdalSeptember + AwdalOctober + AwdalNovember + AwdalDecember + AwdalJanuary + AwdalFebruary + AwdalMarch + BakoolApril + BakoolMay + BakoolJune + BakoolJuly + BakoolAugust + BakoolSeptember + BakoolOctober + BakoolNovember + BakoolDecember + BakoolJanuary + BakoolFebruary + BakoolMarch + BanadirApril + BanadirMay + BanadirJune + BanadirJuly + BanadirAugust + BanadirSeptember + BanadirOctober + BanadirNovember + BanadirDecember + BanadirJanuary + BanadirFebruary + BanadirMarch + BariApril + BariMay + BariJune + BariJuly + BariAugust + BariSeptember + BariOctober + BariNovember + BariDecember + BariJanuary + BariFebruary + BariMarch + BayApril + BayMay + BayJune + BayJuly + BayAugust + BaySeptember + BayOctober + BayNovember + BayDecember + BayJanuary + BayFebruary + BayMarch + GalgaduudApril + GalgaduudMay + GalgaduudJune + GalgaduudJuly + GalgaduudAugust + GalgaduudSeptember + GalgaduudOctober + GalgaduudNovember + GalgaduudDecember + GalgaduudJanuary + GalgaduudFebruary + GalgaduudMarch + GedoApril + GedoMay + GedoJune + GedoJuly + GedoAugust + GedoSeptember + GedoOctober + GedoNovember + GedoDecember + GedoJanuary + GedoFebruary + GedoMarch + HiraanApril + HiraanMay + HiraanJune + HiraanJuly + HiraanAugust + HiraanSeptember + HiraanOctober + HiraanNovember + HiraanDecember + HiraanJanuary + HiraanFebruary + HiraanMarch + Lower_JubaApril + Lower_JubaMay + Lower_JubaJune + Lower_JubaJuly + Lower_JubaAugust + Lower_JubaSeptember + Lower_JubaOctober + Lower_JubaNovember + Lower_JubaDecember + Lower_JubaJanuary + Lower_JubaFebruary + Lower_JubaMarch + Lower_ShabelleApril + Lower_ShabelleMay + Lower_ShabelleJune + Lower_ShabelleJuly + Lower_ShabelleAugust + Lower_ShabelleSeptember + Lower_ShabelleOctober + Lower_ShabelleNovember + Lower_ShabelleDecember + Lower_ShabelleJanuary + Lower_ShabelleFebruary + Lower_ShabelleMarch + Middle_JubaApril + Middle_JubaMay + Middle_JubaJune + Middle_JubaJuly + Middle_JubaAugust + Middle_JubaSeptember + Middle_JubaOctober + Middle_JubaNovember + Middle_JubaDecember + Middle_JubaJanuary + Middle_JubaFebruary + Middle_JubaMarch + Middle_ShabelleApril + Middle_ShabelleMay + Middle_ShabelleJune + Middle_ShabelleJuly + Middle_ShabelleAugust + Middle_ShabelleSeptember + Middle_ShabelleOctober + Middle_ShabelleNovember + Middle_ShabelleDecember + Middle_ShabelleJanuary + Middle_ShabelleFebruary + Middle_ShabelleMarch + MudugApril + MudugMay + MudugJune + MudugJuly + MudugAugust + MudugSeptember + MudugOctober + MudugNovember + MudugDecember + MudugJanuary + MudugFebruary + MudugMarch + NugaalApril + NugaalMay + NugaalJune + NugaalJuly + NugaalAugust + NugaalSeptember + NugaalOctober + NugaalNovember + NugaalDecember + NugaalJanuary + NugaalFebruary + NugaalMarch + SanaagApril + SanaagMay + SanaagJune + SanaagJuly + SanaagAugust + SanaagSeptember + SanaagOctober + SanaagNovember + SanaagDecember + SanaagJanuary + SanaagFebruary + SanaagMarch + SoolApril + SoolMay + SoolJune + SoolJuly + SoolAugust + SoolSeptember + SoolOctober + SoolNovember + SoolDecember + SoolJanuary + SoolFebruary + SoolMarch + TogdheerApril + TogdheerMay + TogdheerJune + TogdheerJuly + TogdheerAugust + TogdheerSeptember + TogdheerOctober + TogdheerNovember + TogdheerDecember + TogdheerJanuary + TogdheerFebruary + TogdheerMarch + Woqooyi_GalbeedApril + Woqooyi_GalbeedMay + Woqooyi_GalbeedJune + Woqooyi_GalbeedJuly + Woqooyi_GalbeedAugust + Woqooyi_GalbeedSeptember + Woqooyi_GalbeedOctober + Woqooyi_GalbeedNovember + Woqooyi_GalbeedDecember + Woqooyi_GalbeedJanuary + Woqooyi_GalbeedFebruary

# %%
lsdv_model = smf.ols(formula=lsdv_expr, data=df_with_dummies)
lsdv_model_results = lsdv_model.fit()
print(lsdv_model_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        conflicts_synth   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.746
# Method:                 Least Squares   F-statistic:                     37.69
# Date:                Tue, 11 Jul 2023   Prob (F-statistic):               0.00
# Time:                        16:38:52   Log-Likelihood:                -3756.8
# No. Observations:                2718   AIC:                             7952.
# Df Residuals:                    2499   BIC:                             9245.
# Df Model:                         218
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.5026      0.291     -1.725      0.085      -1.074       0.069
# TA                           1.2152      0.180      6.733      0.000       0.861       1.569
# PA                           0.8050      0.173      4.658      0.000       0.466       1.144
# DL                           1.0124      0.025     40.350      0.000       0.963       1.062
# Awdal                        0.2159      0.166      1.303      0.193      -0.109       0.541
# Bakool                       0.2743      0.165      1.658      0.097      -0.050       0.599
# Banadir                      0.1802      0.165      1.090      0.276      -0.144       0.504
# Bari                         0.2658      0.166      1.605      0.109      -0.059       0.591
# SoolApril                    0.1863      0.260      0.716      0.474      -0.324       0.697
# SoolMay                     -0.2294      0.261     -0.878      0.380      -0.742       0.283
# SoolJune                     0.1553      0.262      0.592      0.554      -0.359       0.669
# SoolJuly                    -0.1729      0.262     -0.660      0.510      -0.687       0.341
# SoolAugust                   0.2104      0.262      0.803      0.422      -0.303       0.724
# SoolSeptember               -0.4482      0.263     -1.706      0.088      -0.963       0.067
# SoolOctober                 -0.1327      0.262     -0.507      0.612      -0.646       0.381
# SoolNovember                -0.1833      0.270     -0.678      0.498      -0.713       0.347
# SoolDecember                -0.2262      0.275     -0.823      0.411      -0.765       0.313
# SoolJanuary                 -0.2419      0.270     -0.895      0.371      -0.772       0.288
# SoolFebruary                 0.5877      0.270      2.173      0.030       0.057       1.118
# SoolMarch                    0.6819      0.310      2.199      0.028       0.074       1.290
# TogdheerApril                0.1630      0.261      0.624      0.532      -0.349       0.675
# TogdheerMay                  0.1561      0.261      0.599      0.549      -0.355       0.668
# TogdheerJune                -0.0584      0.263     -0.222      0.824      -0.575       0.458
# TogdheerJuly                 0.2326      0.264      0.881      0.378      -0.285       0.750
# TogdheerAugust              -0.0023      0.262     -0.009      0.993      -0.516       0.511
# TogdheerSeptember           -0.0146      0.264     -0.055      0.956      -0.531       0.502
# TogdheerOctober             -0.0353      0.261     -0.135      0.893      -0.547       0.477
# TogdheerNovember            -0.1002      0.271     -0.370      0.711      -0.631       0.431
# TogdheerDecember             0.0268      0.274      0.098      0.922      -0.510       0.563
# TogdheerJanuary             -0.0689      0.270     -0.255      0.799      -0.598       0.461
# TogdheerFebruary            -0.0058      0.271     -0.022      0.983      -0.537       0.525
# TogdheerMarch               -0.0642      0.310     -0.207      0.836      -0.673       0.544
# Woqooyi_GalbeedApril         0.6342      0.308      2.062      0.039       0.031       1.237
# Woqooyi_GalbeedMay          -0.1275      0.306     -0.417      0.677      -0.727       0.472
# Woqooyi_GalbeedJune          0.2479      0.313      0.793      0.428      -0.365       0.861
# Woqooyi_GalbeedJuly         -0.2078      0.323     -0.643      0.521      -0.842       0.426
# Woqooyi_GalbeedAugust       -0.0825      0.320     -0.258      0.796      -0.709       0.544
# Woqooyi_GalbeedSeptember     0.5606      0.313      1.790      0.074      -0.054       1.175
# Woqooyi_GalbeedOctober      -0.1740      0.309     -0.563      0.574      -0.780       0.432
# Woqooyi_GalbeedNovember      0.0346      0.323      0.107      0.915      -0.598       0.667
# Woqooyi_GalbeedDecember      0.2840      0.316      0.899      0.369      -0.335       0.903
# Woqooyi_GalbeedJanuary       0.2839      0.314      0.904      0.366      -0.332       0.900
# Woqooyi_GalbeedFebruary      0.2457      0.316      0.777      0.437      -0.374       0.866
# ==============================================================================
# Omnibus:                        1.791   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.408   Jarque-Bera (JB):                1.713
# Skew:                           0.048   Prob(JB):                        0.425
# Kurtosis:                       3.076   Cond. No.                     5.31e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.29e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
with open('ols_synthetic_data.txt', 'w') as f:
    f.write(lsdv_model_results.summary().as_text())
